# %% [markdown]
# <a href="https://colab.research.google.com/github/Bmartins25/Pratica01_UFJF/blob/main/SIFT_teste_Bruno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread("prt_01_exe01.png", cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread("prt_02_exe02.png", cv2.IMREAD_GRAYSCALE)

# %%
img = cv2.imread("prt_01_exe01.png", cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread("prt_02_exe02.png", cv2.IMREAD_GRAYSCALE)

# %%
sift = cv2.xfeatures2d.SIFT_create()

# %%
keypoints_sift, descriptors = sift.detectAndCompute(img, None)
keypoints_sift, descriptors = sift.detectAndCompute(img2, None) #Detecção de keypoints

# %%
img = cv2.drawKeypoints(img, keypoints_sift, None)   #correspondência entre as imagens(função Drawkeypoints)
img2 = cv2.drawKeypoints(img2, keypoints_sift, None)

# %%
plt.imshow(img),plt.show()
plt.imshow(img2),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7aed21987130>, None)
